# %%
import pandas as pd

# %%
personas= pd.read_csv("personas_2011.csv",sep=";")

# %%
conicet=pd.read_csv("ref_categoria_conicet.csv", sep=";")

# %%
personas.head()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# 1                       255                 3                      5  ...
# 2                       158                 1                     11  ...
# 3                        29                 4                      0  ...
# 4                       280                 3                      8  ...
#
#    producciones_ult_3_anios  producciones_ult_4_anios  institucion_trabajo_id  \
# 0                         1                         1                    4488
# 1                        13                        17                     118
# 2                        13                        13                     587
# 3                         3                         4                      44
# 4                        15                        18                    7310
#
#    seniority_level categoria_conicet_id  categoria_incentivos  \
# 0                                  -1.0                  -1.0
# 1              B                    2.0                   3.0
# 2              D                    NaN                   NaN
# 3                                  -1.0                   4.0
# 4              C                   -1.0                   4.0
#
#    max_dedicacion_horaria_docente_id  institucion_cargo_docente_id  \
# 0                                3.0                         116.0
# 1                                3.0                         118.0
# 2                                NaN                           NaN
# 3                                3.0                         124.0
# 4                                3.0                        6627.0
#
#    clase_cargo_docente_id  tipo_condicion_docente_id
# 0                    22.0                        1.0
# 1                    19.0                        2.0
# 2                     NaN                        NaN
# 3                    21.0                        1.0
# 4                    20.0                        1.0
#
# [5 rows x 21 columns]

# %%
pers= personas[["persona_id","anio","categoria_conicet_id"]]

# %%
pd.merge(pers,conicet,how="right", on="categoria_conicet_id")
# Out:
#        persona_id    anio  categoria_conicet_id  categoria_conicet_descripcion
# 0             1.0  2011.0                  -1.0         No pertenece a Conicet
# 1            10.0  2011.0                  -1.0         No pertenece a Conicet
# 2            11.0  2011.0                  -1.0         No pertenece a Conicet
# 3            12.0  2011.0                  -1.0         No pertenece a Conicet
# 4            13.0  2011.0                  -1.0         No pertenece a Conicet
# ...           ...     ...                   ...                            ...
# 48638     79131.0  2011.0                  11.0          Otro personal Conicet
# 48639     85209.0  2011.0                  11.0          Otro personal Conicet
# 48640    146747.0  2011.0                  11.0          Otro personal Conicet
# 48641         NaN     NaN                  12.0   Investigador correspondiente
# 48642         NaN     NaN                  13.0  Investigador superior emérito
#
# [48643 rows x 4 columns]

# %%
pd.merge(pers, conicet,how="left", on = "categoria_conicet_id")
# Out:
#        persona_id  anio  categoria_conicet_id categoria_conicet_descripcion
# 0               1  2011                  -1.0        No pertenece a Conicet
# 1               5  2011                   2.0          Investigador adjunto
# 2               7  2011                   NaN                           NaN
# 3              10  2011                  -1.0        No pertenece a Conicet
# 4              11  2011                  -1.0        No pertenece a Conicet
# ...           ...   ...                   ...                           ...
# 68547      185558  2011                   NaN                           NaN
# 68548      185574  2011                   NaN                           NaN
# 68549      185583  2011                   NaN                           NaN
# 68550      185590  2011                   NaN                           NaN
# 68551      185608  2011                   NaN                           NaN
#
# [68552 rows x 4 columns]

# %%
pd.merge(pers, conicet,how="outer", on = "categoria_conicet_id")
# Out:
#        persona_id    anio  categoria_conicet_id  categoria_conicet_descripcion
# 0             1.0  2011.0                  -1.0         No pertenece a Conicet
# 1            10.0  2011.0                  -1.0         No pertenece a Conicet
# 2            11.0  2011.0                  -1.0         No pertenece a Conicet
# 3            12.0  2011.0                  -1.0         No pertenece a Conicet
# 4            13.0  2011.0                  -1.0         No pertenece a Conicet
# ...           ...     ...                   ...                            ...
# 68550    146747.0  2011.0                  11.0          Otro personal Conicet
# 68551     47272.0  2011.0                  10.0                        Pasante
# 68552         NaN     NaN                   9.0                    Gestión CyT
# 68553         NaN     NaN                  12.0   Investigador correspondiente
# 68554         NaN     NaN                  13.0  Investigador superior emérito
#
# [68555 rows x 4 columns]

# %%
pd.merge(pers, conicet,how="inner", on = "categoria_conicet_id")
# Out:
#        persona_id  anio  categoria_conicet_id categoria_conicet_descripcion
# 0               1  2011                  -1.0        No pertenece a Conicet
# 1              10  2011                  -1.0        No pertenece a Conicet
# 2              11  2011                  -1.0        No pertenece a Conicet
# 3              12  2011                  -1.0        No pertenece a Conicet
# 4              13  2011                  -1.0        No pertenece a Conicet
# ...           ...   ...                   ...                           ...
# 48635       60260  2011                  11.0         Otro personal Conicet
# 48636       79131  2011                  11.0         Otro personal Conicet
# 48637       85209  2011                  11.0         Otro personal Conicet
# 48638      146747  2011                  11.0         Otro personal Conicet
# 48639       47272  2011                  10.0                       Pasante
#
# [48640 rows x 4 columns]

# %%
df = pd.DataFrame({'mes': [1, 4, 7, 10], 'anio': [2012, 2014, 2013, 2014], 'venta': [55, 40, 84, 31]})
print(df)
# Out:
#    mes  anio  venta
# 0    1  2012     55
# 1    4  2014     40
# 2    7  2013     84
# 3   10  2014     31

# %%
df = pd.DataFrame
({'col1': ['A', 'A', 'B', np.nan, 'D', 'C'], 'col2': [2, 1, 9, 8, 7, 4],'col3': [0, 1, 9, 4, 2, 3],'col4': ['a', 'B', 'c', 'D', 'e', 'F']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive\Documentos\GitHub\Fundamentos_de_informatica_2022\poo_2\pandas\apandas34.ipynb Cell 11' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Documentos/GitHub/Fundamentos_de_informatica_2022/poo_2/pandas/apandas34.ipynb#ch0000010?line=0'>1</a> df = pd.DataFrame({
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Documentos/GitHub/Fundamentos_de_informatica_2022/poo_2/pandas/apandas34.ipynb#ch0000010?line=1'>2</a>     'col1': ['A', 'A', 'B', np.nan, 'D', 'C'],
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Documentos/GitHub/Fundamentos_de_informatica_2022/poo_2/pandas/apandas34.ipynb#ch0000010?line=2'>3</a>     'col2': [2, 1, 9, 8, 7, 4],
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Documentos/GitHub/Fundamentos_de_informatica_2022/poo_2/pandas/apandas34.ipynb#ch0000010?line=3'>4</a>     'col3': [0, 1, 9, 4, 2, 3],
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Documentos/GitHub/Fundamentos_de_informatica_2022/poo_2/pandas/apandas34.ipynb#ch0000010?line=4'>5</a>     'col4': ['a', 'B', 'c', 'D', 'e', 'F']})
#
# NameError: name 'np' is not defined
